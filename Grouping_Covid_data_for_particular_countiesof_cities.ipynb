# %%
import pandas as pd

# %%
df=pd.read_csv("/content/drive/MyDrive/YELP/us-counties.csv")

# %%
df
# Out:
#                date      county       state     fips  cases  deaths
# 0        2020-01-21   Snohomish  Washington  53061.0      1     0.0
# 1        2020-01-22   Snohomish  Washington  53061.0      1     0.0
# 2        2020-01-23   Snohomish  Washington  53061.0      1     0.0
# 3        2020-01-24        Cook    Illinois  17031.0      1     0.0
# 4        2020-01-24   Snohomish  Washington  53061.0      1     0.0
# ...             ...         ...         ...      ...    ...     ...
# 1992097  2021-12-07  Sweetwater     Wyoming  56037.0   8171   103.0
# 1992098  2021-12-07       Teton     Wyoming  56039.0   5425    14.0
# 1992099  2021-12-07       Uinta     Wyoming  56041.0   4076    31.0
# 1992100  2021-12-07    Washakie     Wyoming  56043.0   1857    36.0
# 1992101  2021-12-07      Weston     Wyoming  56045.0   1203    14.0
#
# [1992102 rows x 6 columns]

# %%
# splitting dataframe by groups
# grouping by particular dataframe column
grouped = df.groupby(df.county)
df_suffolk = grouped.get_group("Suffolk")

#df_county = df[df['county'].str.contains(
#'Suffolk|Douglas|Multnomah',
#case=False, na=False)]

# %%
df_suffolk
# Out:
#                date   county          state     fips   cases  deaths
# 44       2020-02-01  Suffolk  Massachusetts  25025.0       1     0.0
# 52       2020-02-02  Suffolk  Massachusetts  25025.0       1     0.0
# 60       2020-02-03  Suffolk  Massachusetts  25025.0       1     0.0
# 68       2020-02-04  Suffolk  Massachusetts  25025.0       1     0.0
# 76       2020-02-05  Suffolk  Massachusetts  25025.0       1     0.0
# ...             ...      ...            ...      ...     ...     ...
# 1984246  2021-12-05  Suffolk       New York  36103.0  260452  3698.0
# 1986842  2021-12-06  Suffolk  Massachusetts  25025.0  115434  1945.0
# 1987496  2021-12-06  Suffolk       New York  36103.0  260951  3701.0
# 1990092  2021-12-07  Suffolk  Massachusetts  25025.0  115874  1946.0
# 1990747  2021-12-07  Suffolk       New York  36103.0  261883  3704.0
#
# [1316 rows x 6 columns]

# %%
grouped = df_suffolk.groupby(df_suffolk.state)
df_suffolk = grouped.get_group("Massachusetts")

# %%
df_suffolk
# Out:
#                date   county          state     fips   cases  deaths
# 44       2020-02-01  Suffolk  Massachusetts  25025.0       1     0.0
# 52       2020-02-02  Suffolk  Massachusetts  25025.0       1     0.0
# 60       2020-02-03  Suffolk  Massachusetts  25025.0       1     0.0
# 68       2020-02-04  Suffolk  Massachusetts  25025.0       1     0.0
# 76       2020-02-05  Suffolk  Massachusetts  25025.0       1     0.0
# ...             ...      ...            ...      ...     ...     ...
# 1977092  2021-12-03  Suffolk  Massachusetts  25025.0  114395  1945.0
# 1980342  2021-12-04  Suffolk  Massachusetts  25025.0  114395  1945.0
# 1983592  2021-12-05  Suffolk  Massachusetts  25025.0  114395  1945.0
# 1986842  2021-12-06  Suffolk  Massachusetts  25025.0  115434  1945.0
# 1990092  2021-12-07  Suffolk  Massachusetts  25025.0  115874  1946.0
#
# [676 rows x 6 columns]

# %%
grouped = df.groupby(df.county)
df_douglas = grouped.get_group("Douglas")

# %%
grouped = df_douglas.groupby(df_douglas.state)
df_douglas = grouped.get_group("Colorado")

# %%
df_douglas
# Out:
#                date   county     state    fips  cases  deaths
# 548      2020-03-05  Douglas  Colorado  8035.0      1     0.0
# 600      2020-03-06  Douglas  Colorado  8035.0      3     0.0
# 678      2020-03-07  Douglas  Colorado  8035.0      3     0.0
# 773      2020-03-08  Douglas  Colorado  8035.0      3     0.0
# 889      2020-03-09  Douglas  Colorado  8035.0      3     0.0
# ...             ...      ...       ...     ...    ...     ...
# 1976114  2021-12-03  Douglas  Colorado  8035.0  46990   347.0
# 1979364  2021-12-04  Douglas  Colorado  8035.0  46990   347.0
# 1982614  2021-12-05  Douglas  Colorado  8035.0  47159   347.0
# 1985864  2021-12-06  Douglas  Colorado  8035.0  47229   348.0
# 1989114  2021-12-07  Douglas  Colorado  8035.0  47511   352.0
#
# [643 rows x 6 columns]

# %%
grouped = df.groupby(df.county)
df_multnomah = grouped.get_group("Multnomah")

# %%
grouped = df_multnomah.groupby(df_multnomah.state)
df_multnomah = grouped.get_group("Oregon")

# %%
df_multnomah
# Out:
#                date     county   state     fips  cases  deaths
# 1112     2020-03-10  Multnomah  Oregon  41051.0      1     0.0
# 1303     2020-03-11  Multnomah  Oregon  41051.0      1     0.0
# 1547     2020-03-12  Multnomah  Oregon  41051.0      1     0.0
# 1843     2020-03-13  Multnomah  Oregon  41051.0      1     0.0
# 2204     2020-03-14  Multnomah  Oregon  41051.0      1     1.0
# ...             ...        ...     ...      ...    ...     ...
# 1978106  2021-12-03  Multnomah  Oregon  41051.0  60720   847.0
# 1981356  2021-12-04  Multnomah  Oregon  41051.0  60720   847.0
# 1984606  2021-12-05  Multnomah  Oregon  41051.0  60720   847.0
# 1987856  2021-12-06  Multnomah  Oregon  41051.0  61066   850.0
# 1991107  2021-12-07  Multnomah  Oregon  41051.0  61160   856.0
#
# [638 rows x 6 columns]

# %%
df_2=df_suffolk.append(df_douglas)

# %%
df_county=df_2.append(df_multnomah)

# %%
df_county
# Out:
#                date     county          state     fips  cases  deaths
# 44       2020-02-01    Suffolk  Massachusetts  25025.0      1     0.0
# 52       2020-02-02    Suffolk  Massachusetts  25025.0      1     0.0
# 60       2020-02-03    Suffolk  Massachusetts  25025.0      1     0.0
# 68       2020-02-04    Suffolk  Massachusetts  25025.0      1     0.0
# 76       2020-02-05    Suffolk  Massachusetts  25025.0      1     0.0
# ...             ...        ...            ...      ...    ...     ...
# 1978106  2021-12-03  Multnomah         Oregon  41051.0  60720   847.0
# 1981356  2021-12-04  Multnomah         Oregon  41051.0  60720   847.0
# 1984606  2021-12-05  Multnomah         Oregon  41051.0  60720   847.0
# 1987856  2021-12-06  Multnomah         Oregon  41051.0  61066   850.0
# 1991107  2021-12-07  Multnomah         Oregon  41051.0  61160   856.0
#
# [1957 rows x 6 columns]

# %%
df_county.to_csv("/content/drive/MyDrive/YELP/covid_county_data2.csv")

# %%
df_new=pd.read_csv("/content/drive/MyDrive/YELP/covid_county_data2.csv")

# %%
df_new
# Out:
#       Unnamed: 0        date     county          state     fips  cases  deaths
# 0             44  2020-02-01    Suffolk  Massachusetts  25025.0      1     0.0
# 1             52  2020-02-02    Suffolk  Massachusetts  25025.0      1     0.0
# 2             60  2020-02-03    Suffolk  Massachusetts  25025.0      1     0.0
# 3             68  2020-02-04    Suffolk  Massachusetts  25025.0      1     0.0
# 4             76  2020-02-05    Suffolk  Massachusetts  25025.0      1     0.0
# ...          ...         ...        ...            ...      ...    ...     ...
# 1952     1978106  2021-12-03  Multnomah         Oregon  41051.0  60720   847.0
# 1953     1981356  2021-12-04  Multnomah         Oregon  41051.0  60720   847.0
# 1954     1984606  2021-12-05  Multnomah         Oregon  41051.0  60720   847.0
# 1955     1987856  2021-12-06  Multnomah         Oregon  41051.0  61066   850.0
# 1956     1991107  2021-12-07  Multnomah         Oregon  41051.0  61160   856.0
#
# [1957 rows x 7 columns]

# %%
df_suffolk.to_csv("/content/drive/MyDrive/YELP/suffolk.csv")

# %%
df_douglas.to_csv("/content/drive/MyDrive/YELP/douglas.csv")

# %%
df_multnomah.to_csv("/content/drive/MyDrive/YELP/multnomah.csv")
