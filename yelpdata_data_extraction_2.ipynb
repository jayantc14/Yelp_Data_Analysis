# %%
import pandas as pd

# %%
df = pd.read_csv("yelp_fourCities.csv")
# Out:
# C:\Users\Jayant\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3058: DtypeWarning: Columns (21) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.columns
# Out:
# Index(['business_id', 'name_x', 'address', 'city', 'state', 'postal_code',
#        'latitude', 'longitude', 'stars', 'review_count_x', 'attributes',
#        'categories', 'user_id', 'review_stars', 'useful_x', 'text', 'date',
#        'name_y', 'review_count_y', 'yelping_since', 'useful_y', 'elite',
#        'friends', 'fans', 'average_stars'],
#       dtype='object')

# %%
cols = ['business_id','user_id', 'review_stars', 'useful_x', 'text', 'date']

# %%
drop_cols = [ 'name_x', 'address', 'postal_code',
       'latitude', 'longitude', 'stars', 'review_count_x', 'attributes',
       'categories','name_y', 'review_count_y', 'yelping_since', 'elite',
       'friends', 'average_stars']

# %%
df = df.drop(drop_cols, axis=1)

# %%
df
# Out:
#                    business_id      city state                 user_id  \
# 0       Kv85DtmBK14Is2YRf7LDIQ  Portland    OR  I-0Be1dHEacp293TeRUDpw
# 1       6DwR5rF1s6fJn4f-Lvfbuw  Portland    OR  I-0Be1dHEacp293TeRUDpw
# 2       BvpABPKyg0w54Xnrt_Ifrg  Portland    OR  I-0Be1dHEacp293TeRUDpw
# 3       FznRWr68zgIV-SkOGNveow  Portland    OR  I-0Be1dHEacp293TeRUDpw
# 4       MRYWsqLbAkPzdKgHeSepZA  Portland    OR  I-0Be1dHEacp293TeRUDpw
# ...                        ...       ...   ...                     ...
# 197944  6f4wzV8gi3SBSbigMFuLdA  Portland    OR  nKN2AJWiArA8IeOUExyB8w
# 197945  Ii-aCAM4KG6RCvpMn0hOkg    Boston    MA  e-DXoZTMNzDOhHMrYZN5zQ
# 197946  Uo6k2_14sdUhVJF9YxnMcg  Portland    OR  iSxnRdziDntu5TL3ki_bfQ
# 197947  aesuEZoyNuctrsKzo-OIUA  Portland    OR  icBK1FERu8d_uU6cBwy2Uw
# 197948  T6cTsRXJ8Yze9DM8L--svA    Boston    MA  NTpDu_zkNJVS0f5a0pTW_g
#
#         review_stars  useful_x  \
# 0                  5         0
# 1                  5         0
# ...

# %%
csv_name = "yelp_3cities_refined2.csv"
df.to_csv(csv_name, index=False)
