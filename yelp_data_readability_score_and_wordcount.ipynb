# %%
import pandas as pd

# %%
df = pd.read_csv("/content/drive/MyDrive/yelp_dataset/yelp_3cities_refined2.csv")

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import nltk
import re
from wordcloud import WordCloud

# %%
pip install textstat
# Out:
# ...
#      |████████████████████████████████| 101 kB 5.6 MB/s
# ...
#      |████████████████████████████████| 2.0 MB 69.4 MB/s
# ...

# %%
import textstat

# %%
dfff = df['text'].to_numpy(copy = False)

# %%
df['Smogscore'] = 0
n = len(dfff)
for epoch in range(n):
  
  t1 = textstat.smog_index(dfff[epoch])
  df.loc[epoch,'Smogscore']  = t1

# %%
df
# Out:
#                    business_id      city state  ... useful_y  fans  Smogscore
# 0       Kv85DtmBK14Is2YRf7LDIQ  Portland    OR  ...      472    18        8.8
# 1       6DwR5rF1s6fJn4f-Lvfbuw  Portland    OR  ...      472    18        7.8
# 2       BvpABPKyg0w54Xnrt_Ifrg  Portland    OR  ...      472    18        8.8
# 3       FznRWr68zgIV-SkOGNveow  Portland    OR  ...      472    18        9.7
# 4       MRYWsqLbAkPzdKgHeSepZA  Portland    OR  ...      472    18        9.7
# ...                        ...       ...   ...  ...      ...   ...        ...
# 197944  6f4wzV8gi3SBSbigMFuLdA  Portland    OR  ...        0     0       10.5
# 197945  Ii-aCAM4KG6RCvpMn0hOkg    Boston    MA  ...        5     1        7.6
# 197946  Uo6k2_14sdUhVJF9YxnMcg  Portland    OR  ...        0     0        9.4
# 197947  aesuEZoyNuctrsKzo-OIUA  Portland    OR  ...        0     0        8.8
# 197948  T6cTsRXJ8Yze9DM8L--svA    Boston    MA  ...        0     0        0.0
#
# [197949 rows x 11 columns]

# %%
import string

# %%
string_text = df['text'].str
df['text'] = string_text.translate(str.maketrans('', '', string.punctuation))

# %%
from nltk.tokenize import word_tokenize

# %%
import nltk
nltk.download('all')
# Out:
# [nltk_data] Downloading collection 'all'
# [nltk_data]    |
# [nltk_data]    | Downloading package abc to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/abc.zip.
# [nltk_data]    | Downloading package alpino to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/alpino.zip.
# [nltk_data]    | Downloading package biocreative_ppi to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/biocreative_ppi.zip.
# [nltk_data]    | Downloading package brown to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/brown.zip.
# [nltk_data]    | Downloading package brown_tei to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/brown_tei.zip.
# [nltk_data]    | Downloading package cess_cat to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/cess_cat.zip.
# [nltk_data]    | Downloading package cess_esp to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/cess_esp.zip.
# ...

# %%
df['review_word_count'] = df['text'].apply(word_tokenize).tolist()
df['review_word_count'] = df['review_word_count'].apply(len)

# %%
df
# Out:
#                    business_id      city  ... Smogscore review_word_count
# 0       Kv85DtmBK14Is2YRf7LDIQ  Portland  ...       8.8                51
# 1       6DwR5rF1s6fJn4f-Lvfbuw  Portland  ...       7.8                29
# 2       BvpABPKyg0w54Xnrt_Ifrg  Portland  ...       8.8                31
# 3       FznRWr68zgIV-SkOGNveow  Portland  ...       9.7                24
# 4       MRYWsqLbAkPzdKgHeSepZA  Portland  ...       9.7                36
# ...                        ...       ...  ...       ...               ...
# 197944  6f4wzV8gi3SBSbigMFuLdA  Portland  ...      10.5                25
# 197945  Ii-aCAM4KG6RCvpMn0hOkg    Boston  ...       7.6                31
# 197946  Uo6k2_14sdUhVJF9YxnMcg  Portland  ...       9.4                72
# 197947  aesuEZoyNuctrsKzo-OIUA  Portland  ...       8.8                32
# 197948  T6cTsRXJ8Yze9DM8L--svA    Boston  ...       0.0               154
#
# [197949 rows x 12 columns]

# %%
df.to_csv('yelp_smog_wordcount.csv')

# %%
df2 = df

# %%
df2.sort_values(by=['date'], inplace=True, ascending=True)

# %%
df2
# Out:
#                    business_id      city  ... Smogscore review_word_count
# 65434   2v0-gBcXethuNFT6rMGiRw    Boston  ...       8.3               166
# 146689  T1wflZohQRZVb9SKQapfFA    Boston  ...       8.4                79
# 136295  uexKxrLmPO5iaXRT9TvWqQ  Portland  ...      13.4               251
# 10234   b4PgITSqSWoPhyJ-Mjko7Q  Portland  ...       0.0                46
# 100914  2EJpVjliJ6Ceijbz9HSpeQ  Portland  ...      12.2                74
# ...                        ...       ...  ...       ...               ...
# 109456  jPzZkfLB06MRbXGTQTjPhQ  Portland  ...       8.5               106
# 133818  IqyqfQFnBsOIReGrcgaYhA    Boston  ...       0.0                32
# 85192   9cGMeGzjfhH85M-Bp9rY9Q  Portland  ...       0.0                37
# 123671  Ro35BZZpDcf92BOKvkhoag  Portland  ...       6.7                29
# 128857  DZm67Anqn1IQTB9iGvw4Fw    Boston  ...       7.2                43
#
# [197949 rows x 12 columns]

# %%
df2.reset_index(drop = True,inplace = True)

# %%
df2
# Out:
#                    business_id      city  ... Smogscore review_word_count
# 0       2v0-gBcXethuNFT6rMGiRw    Boston  ...       8.3               166
# 1       T1wflZohQRZVb9SKQapfFA    Boston  ...       8.4                79
# 2       uexKxrLmPO5iaXRT9TvWqQ  Portland  ...      13.4               251
# 3       b4PgITSqSWoPhyJ-Mjko7Q  Portland  ...       0.0                46
# 4       2EJpVjliJ6Ceijbz9HSpeQ  Portland  ...      12.2                74
# ...                        ...       ...  ...       ...               ...
# 197944  jPzZkfLB06MRbXGTQTjPhQ  Portland  ...       8.5               106
# 197945  IqyqfQFnBsOIReGrcgaYhA    Boston  ...       0.0                32
# 197946  9cGMeGzjfhH85M-Bp9rY9Q  Portland  ...       0.0                37
# 197947  Ro35BZZpDcf92BOKvkhoag  Portland  ...       6.7                29
# 197948  DZm67Anqn1IQTB9iGvw4Fw    Boston  ...       7.2                43
#
# [197949 rows x 12 columns]

# %%
df2.to_csv('/content/drive/MyDrive/yelp_dataset/yelp_smog_wordcount_refined2.csv')
