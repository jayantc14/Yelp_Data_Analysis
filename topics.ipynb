# %% [markdown]
# <a href="https://colab.research.google.com/github/Trisha-Sarwade/Yelp_Data_Analysis/blob/main/topics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

# %%
topic_df = pd.read_csv("/content/drive/MyDrive/yelp_dataset/topic_df.csv")

# %%
topic_df
# Out:
#     Unnamed: 0  topic_num                                             topics
# 0            0          0       ask didnt came told minut server check manag
# 1            1          1                  great food servic place atmospher
# 2            2          2         chicken fri waffl sandwich wing spici sauc
# 3            3          3    pizza crust slice best pie pepperoni place good
# 4            4          4    locat park hotel room store street stay conveni
# 5            5          5            lobster roll chowder clam oyster boston
# 6            6          6                good pretti food veri servic realli
# 7            7          7             ice cream flavor cone scoop cooki salt
# 8            8          8  experi dinner night meal enjoy dine wonder server
# 9            9          9                       food great good cart authent
# 10          10         10           coffe shop latt barista great pastri cup
# ...

# %%
df_topics = pd.read_csv("/content/drive/MyDrive/yelp_dataset/df_topics.csv")

# %%
df_topics.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 0.1', 'Unnamed: 0.1.1', 'business_id', 'city',
#        'state_x', 'user_id', 'review_stars', 'useful_x', 'text', 'date',
#        'useful_y', 'fans', 'Smogscore', 'review_word_count', 'Polarity',
#        'Analysis_TextBlob', 'Vader Sentiment', 'Vader Analysis', 'fips',
#        'cases', 'deaths', 'label', 'word_count', 'resid', 'topic_num',
#        'topics'],
#       dtype='object')

# %%
df_topics.drop(['Unnamed: 0', 'Unnamed: 0.1', 'Unnamed: 0.1.1', 'business_id', 'city',
       'state_x', 'user_id', 'review_stars', 'useful_x', 'date',
       'useful_y', 'fans', 'Smogscore', 'review_word_count', 'Polarity',
       'Analysis_TextBlob', 'Vader Sentiment', 'Vader Analysis', 'fips',
       'cases', 'deaths', 'label', 'word_count'],axis=1, inplace=True)

# %%
li=[32]
  
df_topics[df_topics.topic_num.isin(li)]
# Out:
#                                                      text  ...                                 topics
# 151     Very satisfying The coconut shrimp curry was s...  ...  thai pad food curri best restaur rice
# 169     Good Thai food in the MilwaukieGladstone area ...  ...  thai pad food curri best restaur rice
# 214     Perfect place to have authentic Thai food  The...  ...  thai pad food curri best restaur rice
# 219     The Pad See Ew wasnt great it was kinda sweet ...  ...  thai pad food curri best restaur rice
# 240     This has always been our go to thai place for ...  ...  thai pad food curri best restaur rice
# ...                                                   ...  ...                                    ...
# 197638  This restaurant is forreal great Thai food gra...  ...  thai pad food curri best restaur rice
# 197693  Got the Pad C Ew Pad See Ewe and the chicken w...  ...  thai pad food curri best restaur rice
# ...

# %%
df_topics.loc[197936, "text"]
# Out:
# 'Cuppacoffee is actually quite terrific Its a great atmosphere here You can tell these guys use quality ingredients The service was welcoming and knowledgeable I would gladly return to Cuppacoffee'

# %%
topic_df.loc[17, "topics"]
# Out:
# 'order deliveri pick onlin place readi food takeout'
